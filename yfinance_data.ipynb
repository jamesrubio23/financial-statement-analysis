# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Basic Info

# %%
company_name = "Tesla"
company = yf.Ticker("TSLA")

# %%
company.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-06-04 00:00:00-04:00  345.100006  345.600006  327.329987  332.049988
# 2025-06-05 00:00:00-04:00  322.489990  324.549988  273.209991  284.700012
# 2025-06-06 00:00:00-04:00  298.829987  305.500000  291.140015  295.140015
# 2025-06-09 00:00:00-04:00  285.959991  309.829987  281.850006  308.579987
# 2025-06-10 00:00:00-04:00  314.940002  327.829987  310.670013  326.089996
# 2025-06-11 00:00:00-04:00  334.399994  335.500000  322.500000  326.429993
# 2025-06-12 00:00:00-04:00  323.079987  332.559998  316.859985  319.109985
# 2025-06-13 00:00:00-04:00  313.970001  332.989990  313.299988  325.309998
# 2025-06-16 00:00:00-04:00  331.290009  332.049988  326.410004  329.130005
# 2025-06-17 00:00:00-04:00  326.089996  327.260010  314.739990  316.350006
# 2025-06-18 00:00:00-04:00  317.309998  329.320007  315.450012  322.049988
# 2025-06-20 00:00:00-04:00  327.950012  332.359985  317.779999  322.160004
# ...

# %%
company.info
# Out:
# {'address1': '1 Tesla Road',
#  'city': 'Austin',
#  'state': 'TX',
#  'zip': '78725',
#  'country': 'United States',
#  'phone': '512 516 8177',
#  'website': 'https://www.tesla.com',
#  'industry': 'Auto Manufacturers',
#  'industryKey': 'auto-manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
balance = company.balance_sheet
balance
# Out:
#                                                      2024-12-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                             3216000000.0
# Share Issued                                       3216000000.0
# Total Debt                                        13623000000.0
# Tangible Book Value                               71443000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  36563000000.0
# Other Short Term Investments                      20424000000.0
# Cash And Cash Equivalents                         16139000000.0
# Cash Equivalents                                   1753000000.0
# Cash Financial                                    14386000000.0
#
#                                                      2023-12-31  \
# Treasury Shares Number                                      0.0
# Ordinary Shares Number                             3185000000.0
# ...

# %%
quarterly_balance= company.quarterly_balance_sheet
quarterly_balance
# Out:
#                                                      2025-03-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                             3220000000.0
# Share Issued                                       3220000000.0
# Total Debt                                        13128000000.0
# Tangible Book Value                               74261000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  36996000000.0
# Other Short Term Investments                      20644000000.0
# Cash And Cash Equivalents                         16352000000.0
# Cash Equivalents                                   1452000000.0
# Cash Financial                                    14900000000.0
#
#                                                      2024-12-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                             3216000000.0
# ...

# %% [markdown]
# ## Balance

# %%
balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, Treasury Shares Number to Cash Financial
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2024-12-31 00:00:00  74 non-null     object
#  1   2023-12-31 00:00:00  77 non-null     object
#  2   2022-12-31 00:00:00  77 non-null     object
#  3   2021-12-31 00:00:00  77 non-null     object
#  4   2020-12-31 00:00:00  5 non-null      object
# dtypes: object(5)
# memory usage: 3.8+ KB

# %%
balance.describe()
# Out:
#           2024-12-31  2023-12-31    2022-12-31    2021-12-31   2020-12-31
# count   7.400000e+01        77.0  7.700000e+01  7.700000e+01          5.0
# unique  6.400000e+01        64.0  6.500000e+01  6.800000e+01          5.0
# top     3.216000e+09         0.0  3.164000e+09  3.099000e+09  604000000.0
# freq    2.000000e+00         3.0  2.000000e+00  2.000000e+00          1.0

# %%
for col in balance.columns:
    if balance[col].isnull().sum()>20:
        balance.drop(columns=col, inplace=True)

# %%
balance.reset_index(inplace=True)

# %%
balance
# Out:
#                                                index 2024-12-31 00:00:00  \
# 0                             Treasury Shares Number                 NaN
# 1                             Ordinary Shares Number        3216000000.0
# 2                                       Share Issued        3216000000.0
# 3                                         Total Debt       13623000000.0
# 4                                Tangible Book Value       71443000000.0
# ..                                               ...                 ...
# 76  Cash Cash Equivalents And Short Term Investments       36563000000.0
# 77                      Other Short Term Investments       20424000000.0
# 78                         Cash And Cash Equivalents       16139000000.0
# 79                                  Cash Equivalents        1753000000.0
# 80                                    Cash Financial       14386000000.0
#
#    2023-12-31 00:00:00 2022-12-31 00:00:00 2021-12-31 00:00:00
# ...

# %%
balance_cols = balance.columns

# %%
balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                81 non-null     object
#  1   2024-12-31 00:00:00  74 non-null     object
#  2   2023-12-31 00:00:00  77 non-null     object
#  3   2022-12-31 00:00:00  77 non-null     object
#  4   2021-12-31 00:00:00  77 non-null     object
# dtypes: object(5)
# memory usage: 3.3+ KB

# %%
balance_extended = pd.melt(
    balance,
    id_vars={balance_cols[0]},
    var_name= "Date",
    value_name="Value"
)
balance_extended
# Out:
#                                                 index                 Date  \
# 0                              Treasury Shares Number  2024-12-31 00:00:00
# 1                              Ordinary Shares Number  2024-12-31 00:00:00
# 2                                        Share Issued  2024-12-31 00:00:00
# 3                                          Total Debt  2024-12-31 00:00:00
# 4                                 Tangible Book Value  2024-12-31 00:00:00
# ..                                                ...                  ...
# 319  Cash Cash Equivalents And Short Term Investments  2021-12-31 00:00:00
# 320                      Other Short Term Investments  2021-12-31 00:00:00
# 321                         Cash And Cash Equivalents  2021-12-31 00:00:00
# 322                                  Cash Equivalents  2021-12-31 00:00:00
# 323                                    Cash Financial  2021-12-31 00:00:00
#
#              Value
# 0              NaN
# 1     3216000000.0
# ...

# %% [markdown]
# Pasamos a numérica y a fecha la columna

# %%
balance_extended.dtypes
# Out:
# index    object
# Date     object
# Value    object
# dtype: object

# %%
balance_extended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   324 non-null    object
#  1   Date    324 non-null    object
#  2   Value   305 non-null    object
# dtypes: object(3)
# memory usage: 7.7+ KB

# %%
balance_extended_types = balance_extended.fillna(0)
# Out:
# C:\Users\jaime\AppData\Local\Temp\ipykernel_39212\733573192.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balance_extended_types = balance_extended.fillna(0)

# %%
balance_extended_types['Value'] = pd.to_numeric(balance_extended_types['Value'])

# %%
balance_extended_types['Date'] = pd.to_datetime(balance_extended_types['Date'], format ="yyyy-mm-dd")

# %%
balance_extended_types.dtypes
# Out:
# index            object
# Date     datetime64[ns]
# Value           float64
# dtype: object

# %%
balance_extended_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   324 non-null    object
#  1   Date    324 non-null    datetime64[ns]
#  2   Value   324 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 7.7+ KB

# %%
balance_extended_types['Year'] = balance_extended_types['Date'].dt.year

# %%
balance_extended_types
# Out:
#                                                 index       Date  \
# 0                              Treasury Shares Number 2024-12-31
# 1                              Ordinary Shares Number 2024-12-31
# 2                                        Share Issued 2024-12-31
# 3                                          Total Debt 2024-12-31
# 4                                 Tangible Book Value 2024-12-31
# ..                                                ...        ...
# 319  Cash Cash Equivalents And Short Term Investments 2021-12-31
# 320                      Other Short Term Investments 2021-12-31
# 321                         Cash And Cash Equivalents 2021-12-31
# 322                                  Cash Equivalents 2021-12-31
# 323                                    Cash Financial 2021-12-31
#
#             Value  Year
# 0    0.000000e+00  2024
# 1    3.216000e+09  2024
# 2    3.216000e+09  2024
# 3    1.362300e+10  2024
# 4    7.144300e+10  2024
# ..            ...   ...
# ...

# %% [markdown]
# ## Quarterly balance

# %%
quarterly_balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79 entries, Treasury Shares Number to Cash Financial
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2025-03-31 00:00:00  77 non-null     object
#  1   2024-12-31 00:00:00  74 non-null     object
#  2   2024-09-30 00:00:00  78 non-null     object
#  3   2024-06-30 00:00:00  78 non-null     object
#  4   2024-03-31 00:00:00  78 non-null     object
#  5   2023-12-31 00:00:00  3 non-null      object
# dtypes: object(6)
# memory usage: 4.3+ KB

# %%
quarterly_balance.describe()
# Out:
#         2025-03-31    2024-12-31  2024-09-30  2024-06-30  2024-03-31  \
# count         77.0  7.400000e+01        78.0        78.0        78.0
# unique        64.0  6.400000e+01        64.0        64.0        64.0
# top            0.0  3.216000e+09         0.0         0.0         0.0
# freq           3.0  2.000000e+00         4.0         4.0         3.0
#
#         2023-12-31
# count          3.0
# unique         2.0
# top            0.0
# freq           2.0

# %%
for col in quarterly_balance.columns:
    if quarterly_balance[col].isnull().sum()>20:
        quarterly_balance.drop(columns=col, inplace=True)

# %%
quarterly_balance.reset_index(inplace=True)

# %%
quarterly_balance
# Out:
#                                                index 2025-03-31 00:00:00  \
# 0                             Treasury Shares Number                 NaN
# 1                             Ordinary Shares Number        3220000000.0
# 2                                       Share Issued        3220000000.0
# 3                                         Total Debt       13128000000.0
# 4                                Tangible Book Value       74261000000.0
# ..                                               ...                 ...
# 74  Cash Cash Equivalents And Short Term Investments       36996000000.0
# 75                      Other Short Term Investments       20644000000.0
# 76                         Cash And Cash Equivalents       16352000000.0
# 77                                  Cash Equivalents        1452000000.0
# 78                                    Cash Financial       14900000000.0
#
#    2024-12-31 00:00:00 2024-09-30 00:00:00 2024-06-30 00:00:00  \
# ...

# %%
quarterly_balance_cols = quarterly_balance.columns

# %%
quarterly_balance_extended = pd.melt(
    quarterly_balance,
    id_vars={quarterly_balance_cols[0]},
    var_name= "Date",
    value_name="Value"
)
quarterly_balance_extended
# Out:
#                                                 index                 Date  \
# 0                              Treasury Shares Number  2025-03-31 00:00:00
# 1                              Ordinary Shares Number  2025-03-31 00:00:00
# 2                                        Share Issued  2025-03-31 00:00:00
# 3                                          Total Debt  2025-03-31 00:00:00
# 4                                 Tangible Book Value  2025-03-31 00:00:00
# ..                                                ...                  ...
# 390  Cash Cash Equivalents And Short Term Investments  2024-03-31 00:00:00
# 391                      Other Short Term Investments  2024-03-31 00:00:00
# 392                         Cash And Cash Equivalents  2024-03-31 00:00:00
# 393                                  Cash Equivalents  2024-03-31 00:00:00
# 394                                    Cash Financial  2024-03-31 00:00:00
#
#              Value
# 0              NaN
# 1     3220000000.0
# ...

# %%
quarterly_balance_extended.dtypes
# Out:
# index    object
# Date     object
# Value    object
# dtype: object

# %%
quarterly_balance_extended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   395 non-null    object
#  1   Date    395 non-null    object
#  2   Value   385 non-null    object
# dtypes: object(3)
# memory usage: 9.4+ KB

# %%
quarterly_balance_extended_types = quarterly_balance_extended.copy()
quarterly_balance_extended_types = quarterly_balance_extended_types.fillna(0)
# Out:
# C:\Users\jaime\AppData\Local\Temp\ipykernel_39212\3752723322.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   quarterly_balance_extended_types = quarterly_balance_extended_types.fillna(0)

# %%
quarterly_balance_extended_types['Value'] = pd.to_numeric(quarterly_balance_extended_types['Value'])

# %%
quarterly_balance_extended_types['Date'] = pd.to_datetime(quarterly_balance_extended_types['Date'], format ="yyyy-mm-dd")

# %%
quarterly_balance_extended_types['Year'] = quarterly_balance_extended_types['Date'].dt.year
quarterly_balance_extended_types['Month'] = quarterly_balance_extended_types['Date'].dt.month

# %%
quarterly_balance_extended_types
# Out:
#                                                 index       Date  \
# 0                              Treasury Shares Number 2025-03-31
# 1                              Ordinary Shares Number 2025-03-31
# 2                                        Share Issued 2025-03-31
# 3                                          Total Debt 2025-03-31
# 4                                 Tangible Book Value 2025-03-31
# ..                                                ...        ...
# 390  Cash Cash Equivalents And Short Term Investments 2024-03-31
# 391                      Other Short Term Investments 2024-03-31
# 392                         Cash And Cash Equivalents 2024-03-31
# 393                                  Cash Equivalents 2024-03-31
# 394                                    Cash Financial 2024-03-31
#
#             Value  Year  Month
# 0    0.000000e+00  2025      3
# 1    3.220000e+09  2025      3
# 2    3.220000e+09  2025      3
# 3    1.312800e+10  2025      3
# ...

# %% [markdown]
# # Exportamos archivos

# %%
balance_extended_types.to_excel(f"C:/Users/jaime/Escritorio/Github/X_Financial_Analyst/balance.xlsx")
quarterly_balance_extended_types.to_excel(f"C:/Users/jaime/Escritorio/Github/X_Financial_Analyst/quarterly_balance.xlsx")

# %% [markdown]
# # Competition

# %% [markdown]
# ## Sector 1

# %%
sector_1 = " Electric Vehicles"

# %% [markdown]
# ### Tickers

# %%
tesla_ev_competitors = {
    "BYD": "BYDDY",
    "NIO": "NIO",
    "Xpeng": "XPEV",
    "Li_Auto": "LI",
    "Rivian": "RIVN",
    "Lucid": "LCID",
    "Ford": "F",
    "General_Motors": "GM"
}

# %% [markdown]
# ## Sector 2

# %%
sector_2 = " Energy and batteries"

# %% [markdown]
# ### Tickers

# %%
tesla_energy_competitors = {
    "Enphase_Energy": "ENPH",
    "SolarEdge": "SEDG",
    "SunPower": "SPWR",
    "Fluence_Energy": "FLNC",
    "NextEra_Energy": "NEE"
}

# %% [markdown]
# ## Sector 3

# %%
sector_3 = "Technology"

# %% [markdown]
# ### Tickers

# %%
tesla_ai_competitors = {
    "Waymo_Alphabet": "GOOGL",
    "Cruise_GM": "GM", 
    "Mobileye": "MBLY",
    "Aurora": "AUR",
    "Apple": "AAPL"
}

# %% [markdown]
# ## Sector 4

# %%
sector_4 = "Substitutes Vehicles"

# %% [markdown]
# ### Tickers

# %%
tesla_substitute_competitors = {
    "Toyota": "TM",
    "Honda": "HMC",
    "Nissan": "NSANY",
    "Renault": "RNO",
    "Chevrolet": "GM",      
    "Mercedes_Benz": "MBGYY",
    "BMW": "BMWYY",
    "Audi": "NSU",             
    "Porsche": "POAHY",
    "Volvo": "VOLVY"
}

# %% [markdown]
# # Company historicals

# %%
company_historical = company.history(period='max')

# %%
company_historical.reset_index(inplace=True)

# %%
company_historical
# Out:
#                           Date        Open        High         Low  \
# 0    2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333
# 1    2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333
# 2    2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333
# 3    2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333
# 4    2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333
# ...                        ...         ...         ...         ...
# 3772 2025-06-27 00:00:00-04:00  324.510010  329.339996  317.500000
# 3773 2025-06-30 00:00:00-04:00  319.899994  325.579987  316.600006
# 3774 2025-07-01 00:00:00-04:00  298.459991  305.890015  293.209991
# 3775 2025-07-02 00:00:00-04:00  312.630005  316.829987  303.820007
# 3776 2025-07-03 00:00:00-04:00  317.989990  318.450012  312.760010
#
#            Close     Volume  Dividends  Stock Splits
# 0       1.592667  281494500        0.0           0.0
# 1       1.588667  257806500        0.0           0.0
# ...

# %%
company_historical.dtypes
# Out:
# Date            datetime64[ns, America/New_York]
# Open                                     float64
# High                                     float64
# Low                                      float64
# Close                                    float64
# Volume                                     int64
# Dividends                                float64
# Stock Splits                             float64
# dtype: object

# %%
company_historical['Date'] = pd.to_datetime(company_historical['Date']).dt.date

# %%
company_historical
# Out:
#             Date     Open     High      Low    Close     Volume  Dividends  \
# 0     2010-06-29    1.267    1.667    1.169    1.593  281494500        0.0
# 1     2010-06-30    1.719    2.028    1.553    1.589  257806500        0.0
# 2     2010-07-01    1.667    1.728    1.351    1.464  123282000        0.0
# 3     2010-07-02    1.533    1.540    1.247    1.280   77097000        0.0
# 4     2010-07-06    1.333    1.333    1.055    1.074  103003500        0.0
# ...          ...      ...      ...      ...      ...        ...        ...
# 3772  2025-06-27  324.510  329.340  317.500  323.630   89067000        0.0
# 3773  2025-06-30  319.900  325.580  316.600  317.660   76695100        0.0
# 3774  2025-07-01  298.460  305.890  293.210  300.710  145085700        0.0
# 3775  2025-07-02  312.630  316.830  303.820  315.650  119483700        0.0
# 3776  2025-07-03  317.990  318.450  312.760  315.350   58042300        0.0
#
#       Stock Splits
# 0              0.0
# 1              0.0
# ...

# %%
company_historical.dtypes
# Out:
# Date            datetime64[ns, America/New_York]
# Open                                     float64
# High                                     float64
# Low                                      float64
# Close                                    float64
# Volume                                     int64
# Dividends                                float64
# Stock Splits                             float64
# dtype: object

# %%
columns = ['Open', 'High', 'Low', 'Close']
company_historical[columns] = company_historical[columns].apply(lambda x: round(x,3))

# %%
def preprocess_historical_data(df):
    df.reset_index(inplace=True)
    df['Date'] = pd.to_datetime(df['Date']).dt.date
    columns = ['Open', 'High', 'Low', 'Close']
    df[columns] = df[columns].apply(lambda x: round(x,3))

    return df

# %% [markdown]
# # Comparing historicals with competition

# %% [markdown]
# ## Sector 1

# %%
tesla_ev_competitors_dict = {}

for competitor in tesla_ev_competitors:
    print(competitor)
    tesla_ev_competitors_dict[competitor] = preprocess_historical_data(company.history(period='max'))
# Out:
# BYD
# NIO
# Xpeng
# Li_Auto
# Rivian
# Lucid
# Ford
# General_Motors

# %%
tesla_ev_competitors_dict['BYD']
# Out:
#             Date     Open     High      Low    Close     Volume  Dividends  \
# 0     2010-06-29    1.267    1.667    1.169    1.593  281494500        0.0
# 1     2010-06-30    1.719    2.028    1.553    1.589  257806500        0.0
# 2     2010-07-01    1.667    1.728    1.351    1.464  123282000        0.0
# 3     2010-07-02    1.533    1.540    1.247    1.280   77097000        0.0
# 4     2010-07-06    1.333    1.333    1.055    1.074  103003500        0.0
# ...          ...      ...      ...      ...      ...        ...        ...
# 3772  2025-06-27  324.510  329.340  317.500  323.630   89067000        0.0
# 3773  2025-06-30  319.900  325.580  316.600  317.660   76695100        0.0
# 3774  2025-07-01  298.460  305.890  293.210  300.710  145085700        0.0
# 3775  2025-07-02  312.630  316.830  303.820  315.650  119483700        0.0
# 3776  2025-07-03  317.990  318.450  312.760  315.350   58042300        0.0
#
#       Stock Splits
# 0              0.0
# 1              0.0
# ...

# %%
with pd.ExcelWriter('C:/Users/jaime/Escritorio/Github/X_Financial_Analyst/tesla_ev_competitors.xlsx', engine='openpyxl') as writer:
    for df_name, df in tesla_ev_competitors_dict.items():
        df.to_excel(writer, sheet_name=df_name)

# %% [markdown]
# ## Sector 2

# %% [markdown]
# ## Sector 3

# %% [markdown]
# ## Sector 4
